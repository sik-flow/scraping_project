# %% [markdown]
# # What is the difference between a Data Scientist and a Data Analyst?

# %% [markdown]
# As our online and in-person data scientist programs are maturing there is interest from both the Product and Curriculum teams on having data-driven insights on the data science job market to make sure that the Flatiron school's offerings and marketing best fit the evolving data science job market our graduates are heading into.
#
# The first step in this exploration is to try and get more clear definitions as to the difference between a data scientist and a data analyst. It is well known in the data science community that the understanding of the field among the general market, hiring managers, and HR recruiters is quite variable and there is significant overlap between roles that have widely varying titles. To try and get some clarity we have scraped a dataset from LinkedIn covering data scientist and data analyst roles and filtered it for roles in NYC, Atlanta, and Kansas City, MO aiming to incorporate listings from a major tech hub, a developing tech hub, and a non-technical job market so as to be representative of the variety of job markets our graduates will be entering.

# %%
#library imports - obtain, scrub, explore
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# OBTAIN

# %%
df = pd.read_csv('Data/jobs.csv')
df = pd.DataFrame(df)
df.head()
# Out:
#                        company  \
# 0                      Loftium
# 1                    Zume Inc.
# 2  TRC Staffing Services, Inc.
# 3                        bidco
# 4                    Compass /
#
#                                          description           job_cat  \
# 0  About the role\nMachine learning is core to ou...  machine learning
# 1  Who We Are\n\nZume is on a quest to be the mos...  machine learning
# 2  The goal is to lead the processes from infrast...  machine learning
# 3  We are looking for a Machine Learning Engineer...  machine learning
# 4  Engineering\n\nMachine Learning Engineer\n\nSe...  machine learning
#
#            loc                            location  \
# 0  Seattle, WA  Seattle, Washington, United States
# 1  Seattle, WA                     Seattle, WA, US
# 2  Seattle, WA                     Seattle, WA, US
# 3  Seattle, WA                     Seattle, WA, US
# 4  Seattle, WA                     Seattle, WA, US
#
#                                position position_low
# 0             Machine Learning Engineer          NaN
# 1  Machine Learning Engineer - Platform          NaN
# 2             Machine Learning Engineer          NaN
# 3             Machine Learning Engineer          NaN
# 4             Machine Learning Engineer          NaN

# %%
df = df.drop(['location','position_low'], axis=1)

# %%
locations = ['NY', 'KCMO', 'ATL']
roles = ['data scientist', 'data analyst']
# df['loc'].unique()
df_filteredbyloc = df[df['loc'].isin(locations)]
df_filteredbyloc = df_filteredbyloc[df_filteredbyloc['job_cat'].isin(roles)].reset_index()
df_filteredbyloc.head()
# Out:
#    index         company                                        description  \
# 0   2078  PRI Technology  Sr. Data Scientist\n\nThe Sr. Data Scientist i...
# 1   2079   StevenDouglas  POSITION SUMMARY:\nThe Data Scientist provides...
# 2   2080  Experience LLC  When your team hits a game winner or the band ...
# 3   2081          Arby's  Purpose Of The Position\n\nAn Inspire data sci...
# 4   2082  Collabera Inc.  Atlanta, Georgia\nSkills : python ,r ,scala ,j...
#
#           job_cat  loc            position
# 0  data scientist  ATL  Sr. Data Scientist
# 1  data scientist  ATL      Data Scientist
# 2  data scientist  ATL      Data Scientist
# 3  data scientist  ATL      Data Scientist
# 4  data scientist  ATL      Data Scientist

# %% [markdown]
# DATA CLEANING - NLP PREP

# %%
import nltk, re
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec, Doc2Vec, TfidfModel
from gensim.models.phrases import Phraser, Phrases
# Out:
# [nltk_data] Downloading package punkt to /Users/blewis2/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stopword_set = stopwords.words('english')
stopword_set = stopword_set + ["need", "goal", "include", "looking", "seeking"] + list(string.punctuation)

# %%
stopword_set_titles = stopword_set + ['data scientist', 'data analyst']

# %%
def cleaner(text, stopwords=stopwords.words('english'), symbols = "?&()*%$#@.!:;^"):
    text = text.replace("\n", " ").replace("*", " ").strip().replace("-", "_")
    for symbol in symbols:
        text = text.replace(symbol, " ")
    text = text.lower()
    text = re.sub(" +", " ", text)
    new_text = []
    for word in text.split(" "):
        if word in stopwords or word == ' ' or word == '':
            continue
        else:
            new_text.append(word)
    return new_text

# %%
descriptions = df_filteredbyloc.description 
descriptions = [cleaner(d, stopwords=stopword_set) for d in descriptions]
df_filteredbyloc['descriptions'] = descriptions

# %%
descriptions[:10]
# Out:
# [['sr',
#   'data',
#   'scientist',
#   'sr',
#   'data',
#   'scientist',
#   'driven',
#   'interest',
#   'solving',
#   'complex',
#   'problems',
#   'data',
#   'exploration',
#   'analysis',
#   'highly',
#   'analytically',
#   'minded',
#   'robust',
#   'technical',
#   'tool',
#   'kit',
#   'substantial',
#   'experience',
#   'analytics',
#   'portfolio',
#   'successfully',
#   'executed',
#   'models',
#   'sr',
#   'data',
#   'scientist',
#   'responsible',
#   'executing',
#   'steps',
#   'modeling',
#   'process',
#   'produce',
#   'high',
#   'quality,',
#   'reproducible',
#   'results',
#   'work',
#   'team',
#   'analyst',
#   'support',
#   'development',
#   'processes',
#   'technologies',
#   'improve',
#   'patient',
#   'outcomes',
#   'role',
#   'responsible',
#   'extracting,',
#   'managing,',
#   'analyzing',
#   'complex',
#   'administrative',
#   'healthcare',
#   'data',
#   'applying',
#   'client/ai',
#   'concepts',
#   'uncover',
#   'opportunities',
#   'process',
#   'improvement',
#   'responsibilities',
#   'develop',
#   'algorithms',
#   'applications',
#   'apply',
#   'mathematics',
#   'data,',
#   'perform',
#   'large',
#   'scale',
#   'experimentation',
#   'develop',
#   'functionality',
#   'work',
#   'large',
#   'scale',
#   'real_world',
#   'health',
#   'data',
#   'evidence',
#   'generation',
#   'drive',
#   'innovation',
#   'via',
#   'use',
#   'data',
#   'driven',
#   'insights',
#   'customers',
#   'biggest',
#   'problems',
#   'build',
#   'advocate',
#   'data_driven',
#   'solutions',
#   'help',
#   'customers',
#   'improve',
#   'clinical',
#   'outcomes',
#   'processes',
#   'design',
#   'build',
#   'scalable',
#   'production_ready',
#   'analytics',
#   'solutions',
#   'using',
#   'wide',
#   'array',
#   'techniques',
#   'methodologies',
#   'field',
#   'statistical',
#   'modeling,',
#   'machine',
#   'learning,',
#   'ai',
#   'technologies',
#   'meet',
#   'needs',
#   'given',
#   'client',
#   'engagements',
#   'design',
#   'develop',
#   'deep',
#   'learning,',
#   'machine',
#   'learning,',
#   'data',
#   'mining,',
#   'r,',
#   'python,',
#   'statistical',
#   'models,',
#   'data',
#   'analysis',
#   'techniques',
#   'collect,',
#   'explore,',
#   'extract',
#   'insights',
#   'structured',
#   'unstructured',
#   'electronic',
#   'health',
#   'record',
#   'data',
#   'create',
#   'dashboards',
#   'presentations',
#   'communicate',
#   'analytic',
#   'findings',
#   'requirements',
#   'minimum',
#   "bachelor's",
#   'degree',
#   'computer',
#   'science,',
#   'engineering,',
#   'physics,',
#   'highly',
#   'quantitative',
#   'technically',
#   'oriented',
#   'field,',
#   "master's",
#   'degree',
#   'preferred',
#   '5+',
#   'years',
#   'professional',
#   'work',
#   'experience',
#   'quantitative',
#   'analyst',
#   'applied',
#   'analytics',
#   'technical',
#   'leader',
#   'healthcare',
#   'experience',
#   'preferred',
#   'mastery',
#   'statistical',
#   'software,',
#   'scripting',
#   'languages,',
#   'packages_',
#   'preferred',
#   'r,',
#   'python,',
#   'sql',
#   'prior',
#   'experience',
#   'natural',
#   'language',
#   'processing',
#   'using',
#   'nltk',
#   'sql',
#   'knowledge',
#   'experience',
#   'working',
#   'relational',
#   'databases,',
#   'query',
#   'authoring',
#   'sql',
#   'well',
#   'working',
#   'familiarity',
#   'variety',
#   'databases/date_sources',
#   'solid',
#   'understanding',
#   'data',
#   'structures,',
#   'software',
#   'design',
#   'architecture',
#   'ability',
#   'work',
#   'independently',
#   'take',
#   'initiative,',
#   'also',
#   'co_operative',
#   'team',
#   'player',
#   'proficient',
#   'interpreting',
#   'business',
#   'questions',
#   'applying',
#   'concepts',
#   'data'],
#  ['position',
#   'summary',
#   'data',
#   'scientist',
#   'provides',
#   'merchandizing,',
#   'sales,',
#   'marketing',
#   'teams',
#   'insights',
#   'gained',
#   'discovery',
#   'analysis',
#   'promote',
#   'data',
#   'driven',
#   'decision',
#   'making',
#   'process',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'skills',
#   'essential',
#   'interpreting',
#   'data',
#   'responsibilities',
#   'work',
#   'stakeholders',
#   'throughout',
#   'organization',
#   'identify',
#   'opportunities',
#   'leveraging',
#   'company',
#   'data',
#   'drive',
#   'business',
#   'solutions',
#   'mine',
#   'analyze',
#   'data',
#   'company',
#   'databases',
#   'drive',
#   'optimization',
#   'improvement',
#   'product',
#   'development,',
#   'marketing',
#   'techniques',
#   'business',
#   'strategies',
#   'assess',
#   'effectiveness',
#   'accuracy',
#   'new',
#   'data',
#   'sources',
#   'data',
#   'gathering',
#   'techniques',
#   'develop',
#   'custom',
#   'data',
#   'models',
#   'algorithms',
#   'apply',
#   'data',
#   'sets',
#   'use',
#   'predictive',
#   'modeling',
#   'increase',
#   'optimize',
#   'customer',
#   'experiences,',
#   'revenue',
#   'generation,',
#   'ad',
#   'targeting',
#   'business',
#   'outcomes',
#   'develop',
#   'company',
#   'a/b',
#   'testing',
#   'framework',
#   'test',
#   'model',
#   'quality',
#   'coordinate',
#   'different',
#   'functional',
#   'teams',
#   'implement',
#   'models',
#   'monitor',
#   'outcomes',
#   'develop',
#   'processes',
#   'tools',
#   'monitor',
#   'analyze',
#   'model',
#   'performance',
#   'data',
#   'accuracy',
#   'qualifications',
#   'master’s',
#   'statistics,',
#   'mathematics,',
#   'computer',
#   'science',
#   'another',
#   'quantitative',
#   'field',
#   'least',
#   '2_3',
#   'years',
#   'experience',
#   'manipulating',
#   'data',
#   'sets',
#   'building',
#   'statistical',
#   'models',
#   'experience',
#   'using',
#   'statistical',
#   'computer',
#   'languages',
#   'r,',
#   'python',
#   'manipulate',
#   'data',
#   'draw',
#   'insights',
#   'large',
#   'data',
#   'sets',
#   'experience',
#   'distributed',
#   'data/computing',
#   'tools',
#   'hadoop,',
#   'hive,',
#   'spark,',
#   'sql',
#   'experience',
#   'working',
#   'creating',
#   'data',
#   'architectures',
#   'knowledge',
#   'experience',
#   'statistical',
#   'data',
#   'mining',
#   'techniques',
#   'regression,',
#   'random',
#   'forest,',
#   'boosting,',
#   'trees,',
#   'text',
#   'mining',
#   'knowledge',
#   'deep',
#   'learning/ai',
#   'techniques',
#   'platforms',
#   'rnns,',
#   'cnns,',
#   'tensorflow,',
#   'mxnet',
#   'knowledge',
#   'advanced',
#   'statistical',
#   'techniques',
#   'concepts',
#   'regression,',
#   'properties',
#   'distributions,',
#   'statistical',
#   'tests,',
#   'experiment',
#   'design',
#   'experience',
#   'applications',
#   'drive',
#   'learn',
#   'master',
#   'new',
#   'technologies',
#   'techniques'],
#  ['team',
#   'hits',
#   'game',
#   'winner',
#   'band',
#   'plays',
#   'favorite',
#   'song,',
#   'nothing',
#   'like',
#   'experiencing',
#   'moment',
#   'live',
#   'in_person',
#   '“experience”,',
#   'expapp',
#   'com,',
#   'mission',
#   'connect',
#   'people',
#   'unforgettable',
#   'live',
#   'experiences',
#   'mobile',
#   'technology',
#   'move',
#   'people',
#   'couch',
#   'crowd',
#   'whether',
#   'it’s',
#   'securing',
#   'tickets,',
#   'upgrading',
#   'fantastic',
#   'seat,',
#   'participating',
#   'lifetime',
#   'experience,',
#   'sports',
#   'entertainment',
#   'companies',
#   'fans',
#   'alike',
#   'realize',
#   'opportunities',
#   'longer',
#   'wasted',
#   'experienced',
#   'data',
#   'scientist',
#   'join',
#   'rapidly',
#   'growing',
#   'team',
#   'candidates',
#   'must',
#   'passion',
#   'things',
#   'data',
#   'ready',
#   'create',
#   'next_generation',
#   'data',
#   'science',
#   'power',
#   'company',
#   'reshaping',
#   'industry',
#   'role',
#   'offers',
#   'unique',
#   'opportunity',
#   'disrupt',
#   '20_billion',
#   'dollar',
#   'ticketing',
#   'industry',
#   'innovative',
#   'technology',
#   'part',
#   'fast_paced,',
#   'collaborative',
#   'team',
#   'exciting',
#   'role,',
#   'create',
#   'predictive',
#   'models',
#   'power',
#   'innovative',
#   'ticketing',
#   'products',
#   'acquire',
#   'explore',
#   'data',
#   'creative',
#   'sources',
#   'power',
#   'data',
#   'science',
#   'initiatives',
#   'create',
#   'data',
#   'pipelines',
#   'applications',
#   'amazon',
#   'web',
#   'services',
#   'environments',
#   'mine',
#   'analyze',
#   'data',
#   'company',
#   'databases',
#   'drive',
#   'optimization',
#   'improvement',
#   'product',
#   'development,',
#   'marketing',
#   'techniques',
#   'business',
#   'strategies',
#   'use',
#   'predictive',
#   'modeling',
#   'increase',
#   'optimize',
#   'customer',
#   'experiences,',
#   'revenue',
#   'generation,',
#   'ad',
#   'targeting',
#   'business',
#   'outcomes',
#   'coordinate',
#   'different',
#   'functional',
#   'teams',
#   'implement',
#   'models',
#   'monitor',
#   'outcomes',
#   'develop',
#   'processes',
#   'tools',
#   'monitor',
#   'analyze',
#   'model',
#   'performance',
#   'data',
#   'accuracy',
#   'interact',
#   'project',
#   'stakeholders',
#   'provide',
#   'data',
#   'science',
#   'solutions',
#   'addressing',
#   'business',
#   'requirements',
#   'must',
#   'bachelor’s',
#   'degree',
#   '3_7',
#   'years',
#   'data',
#   'science',
#   'analytics',
#   'experience',
#   'experience',
#   'creating',
#   'using',
#   'advanced',
#   'machine',
#   'learning',
#   'algorithms',
#   'statistics',
#   'regression,',
#   'simulation,',
#   'scenario',
#   'analysis,',
#   'modeling,',
#   'clustering,',
#   'decision',
#   'trees,',
#   'neural',
#   'networks,',
#   'etc',
#   'experience',
#   'creating',
#   'deploying',
#   'data',
#   'science',
#   'solutions',
#   'cloud',
#   'environment',
#   'aws',
#   'preferred',
#   'experience',
#   'using',
#   'statistical',
#   'computer',
#   'languages',
#   'python,',
#   'sql,',
#   'scala',
#   'manipulate',
#   'data',
#   'draw',
#   'insights',
#   'large',
#   'data',
#   'sets',
#   'experience',
#   'working',
#   'creating',
#   'data',
#   'architectures',
#   'knowledge',
#   'variety',
#   'machine',
#   'learning',
#   'techniques',
#   'clustering,',
#   'decision',
#   'tree',
#   'learning,',
#   'artificial',
#   'neural',
#   'networks,',
#   'etc',
#   'real_world',
#   'advantages/drawbacks',
#   'experience',
#   'visualizing/presenting',
#   'data',
#   'stakeholders',
#   'using',
#   'tableau,',
#   'excel,',
#   'etc',
#   'strong',
#   'problem',
#   'solving',
#   'skills',
#   'emphasis',
#   'product',
#   'development',
#   'excellent',
#   'written',
#   'verbal',
#   'communication',
#   'skills',
#   'coordinating',
#   'across',
#   'teams',
#   'drive',
#   'learn',
#   'master',
#   'new',
#   'technologies',
#   'techniques',
#   'nice',
#   'advanced',
#   'degree',
#   'math,',
#   'statistics',
#   'computer',
#   'science,',
#   'economics',
#   'another',
#   'data_related',
#   'field',
#   'coding',
#   'knowledge',
#   'experience',
#   'several',
#   'languages',
#   'grails,',
#   'java,',
#   'javascript,',
#   'python',
#   'experience',
#   'multiple',
#   'aws',
#   'products',
#   'lambda,',
#   'sagemaker,',
#   'athena,',
#   'ec2,',
#   'emr,',
#   'redshift,',
#   'glue,',
#   's3',
#   'experience',
#   'managing',
#   'digital',
#   'data',
#   'across',
#   'web',
#   'pages',
#   'mobile',
#   'applications',
#   'tableau',
#   'experience',
#   'experience',
#   'digital',
#   'analytics',
#   'tools',
#   'google',
#   'analytics,',
#   'adobe',
#   'analytics,',
#   'mixpanel,',
#   'etc',
#   'work',
#   'perks',
#   'work',
#   'proven',
#   'incredibly',
#   'talented',
#   'team',
#   'medical',
#   'dental',
#   'vision',
#   'coverage',
#   '401k',
#   'match',
#   'inwego',
#   'membership',
#   'plus',
#   'one',
#   'in_office',
#   'massage',
#   'therapists',
#   'work',
#   'new',
#   'macbook',
#   'pro',
#   'retina',
#   'laptop',
#   'open,',
#   'fun',
#   'comfortable',
#   'workspace',
#   'cubes',
#   'coffee',
#   'bar',
#   'keeps',
#   'us',
#   'going',
#   'beverages',
#   'healthy',
#   'snacks',
#   '75″',
#   'television',
#   'work',
#   'area',
#   'work',
#   'demos',
#   'maybe',
#   'watching',
#   'football',
#   'break_out',
#   'rooms',
#   'small',
#   'meetings,',
#   'privacy,',
#   'quiet',
#   'space',
#   'robot',
#   'pushes',
#   'code,',
#   'makes',
#   'jokes,',
#   'runs',
#   'automated',
#   'tests',
#   'ping_pong',
#   'table,',
#   'xbox,',
#   'nintendo',
#   '64',
#   'bring',
#   'game',
#   'dj',
#   'sonos',
#   'throughout',
#   'office',
#   'pennant',
#   'university',
#   'hung',
#   'pride',
#   'office',
#   'equal',
#   'employment',
#   'opportunity',
#   'eeo',
#   'we’re',
#   'equal',
#   'opportunity',
#   'employer',
#   'comply',
#   'applicable',
#   'federal,',
#   'state,',
#   'local',
#   'fair',
#   'employment',
#   'practices',
#   'laws',
#   'strictly',
#   'prohibit',
#   'tolerate',
#   'discrimination',
#   'employees,',
#   'applicants,',
#   'covered',
#   'persons',
#   'race,',
#   'color,',
#   'religion,',
#   'creed,',
#   'national',
#   'origin',
#   'ancestry,',
#   'ethnicity,',
#   'sex,',
#   'gender',
#   'including',
#   'gender',
#   'nonconformity',
#   'status',
#   'transgender',
#   'transsexual',
#   'individual',
#   'sexual',
#   'orientation,',
#   'marital',
#   'status,',
#   'age,',
#   'physical',
#   'mental',
#   'disability,',
#   'citizenship,',
#   'past,',
#   'current',
#   'prospective',
#   'service',
#   'uniformed',
#   'services,',
#   'predisposing',
#   'genetic',
#   'characteristic,',
#   'domestic',
#   'violence',
#   'victim',
#   'status,',
#   'arrest',
#   'records,',
#   'characteristic',
#   'protected',
#   'applicable',
#   'federal,',
#   'state',
#   'local',
#   'law'],
#  ['purpose',
#   'position',
#   'inspire',
#   'data',
#   'scientist',
#   'opportunity',
#   'work',
#   'various',
#   'data',
#   'science',
#   'projects',
#   'across',
#   'inspire',
#   'portfolio',
#   "arby's,",
#   'bww,',
#   'rusty',
#   'taco,',
#   'sonic',
#   'role',
#   'facilitate',
#   'end_to_end',
#   'development,',
#   'testing,'],
#  ['atlanta,',
#   'georgia',
#   'skills',
#   'python',
#   ',r',
#   ',scala',
#   ',java,cloud,redhat,aws,kubernetes,scikit,docker,postgress,api,jdbc,sql,kerberos',
#   'description',
#   'data',
#   'scientist',
#   'position',
#   'atlanta,',
#   'georgia',
#   'strong',
#   'experience',
#   'software',
#   'development',
#   'python,',
#   'r,',
#   'scala,',
#   'java',
#   'open',
#   'programming',
#   'languages',
#   'strong',
#   'knowledge',
#   'machine',
#   'learning',
#   'models',
#   'python,',
#   'r',
#   'tensorflow',
#   'based',
#   'strong',
#   'knowledge',
#   'machine',
#   'learning',
#   'platforms',
#   'including',
#   'public',
#   'cloud',
#   'offering',
#   'strong',
#   'experience',
#   'red',
#   'hat',
#   'enterprise',
#   'linux',
#   'rhel',
#   'operating',
#   'system,',
#   'tools,',
#   'command',
#   'lines,',
#   'etc',
#   'strong',
#   'experience',
#   'kubernetes',
#   'and/or',
#   'aws',
#   'eks',
#   'experience',
#   'supporting',
#   'using',
#   'products',
#   'associated',
#   'machine',
#   'learning/ai',
#   'develpment',
#   'deployment',
#   'models',
#   'aws',
#   'experience',
#   'product',
#   'development',
#   'lifecycle',
#   'including',
#   'quality',
#   'assurance,',
#   'code',
#   'management,',
#   'code',
#   'deployment',
#   'tools',
#   'experience',
#   'defining',
#   'runtime',
#   'needs',
#   'software',
#   'facilitate',
#   'application,',
#   'runtime',
#   'middleware',
#   'components',
#   'machine',
#   'learning',
#   'models',
#   'experience',
#   'using',
#   'scikit_learn,',
#   'tensorflow',
#   'and/or',
#   'keras',
#   'experience',
#   'translating',
#   'requirements',
#   'working',
#   'prototypes',
#   'use',
#   'iterative',
#   'development',
#   'practices',
#   'experience',
#   'machine',
#   'learning',
#   'build',
#   'containers/depl',
#   'oy',
#   'containers/container',
#   'registry',
#   'gitlab',
#   'experience',
#   'docker,',
#   'postgress',
#   'puppet',
#   'automation',
#   'needs',
#   'experience',
#   'developing',
#   'apis',
#   'experience',
#   'usage',
#   'ci/cd',
#   'pipeline',
#   'e',
#   'gitlab,',
#   'gitlabrunner',
#   'knowledge',
#   'experience',
#   'nvidia_docker,',
#   'gpu',
#   'specific',
#   'technologies',
#   'knowledge',
#   'clustered',
#   'computing',
#   'resource',
#   'impacts',
#   'different',
#   'processing',
#   'types',
#   'knowledge',
#   'data',
#   'store',
#   'integration',
#   'jdbc',
#   'connectivity',
#   'security',
#   'connectively',
#   'platforms',
#   'knowledge',
#   'proactive',
#   'monitoring',
#   'technologies',
#   'knowledge',
#   'experience',
#   'sql,',
#   'etl,',
#   'data',
#   'wrangling',
#   'knowledge',
#   'data',
#   'store',
#   'integration',
#   'jdbc',
#   'connectivity',
#   'security',
#   'connectively',
#   'platforms',
#   'basic',
#   'understanding',
#   'security',
#   'protocols',
#   'e',
#   'kerberos',
#   'basic',
#   'understanding',
#   'network',
#   'technologies',
#   'e',
#   'data',
#   'traffic',
#   'basic',
#   'understanding',
#   'gpu',
#   'use',
#   'deep',
#   'learning',
#   'inference',
#   'plus',
#   'basic',
#   'understanding',
#   'network',
#   'technologies',
#   'e',
#   'data',
#   'traffic'],
#  ['clearance',
#   'level',
#   'must',
#   'currently',
#   'possess',
#   'active',
#   'clearance',
#   'required',
#   'clearance',
#   'level',
#   'must',
#   'able',
#   'obtain',
#   'active',
#   'clearance',
#   'required',
#   'suitability',
#   'suitability',
#   'required',
#   'job',
#   'family',
#   'scientists',
#   'job',
#   'description',
#   'position',
#   'yet',
#   'funded',
#   'gdit',
#   'future',
#   'opportunity',
#   'data',
#   'scientist',
#   'experienced',
#   'data',
#   'modeling',
#   'analytics',
#   'join',
#   'team',
#   'supporting',
#   'national',
#   'health',
#   'care',
#   'data',
#   'analytics',
#   'program',
#   'atlanta',
#   'ga',
#   'part',
#   'data',
#   'science',
#   'team',
#   'incumbent',
#   'responsible',
#   'identifying',
#   'applying',
#   'data',
#   'science',
#   'methods',
#   'predictive',
#   'analytics,',
#   'ai/ml,',
#   'reporting,',
#   'dashboards',
#   'complex',
#   'health',
#   'care',
#   'data',
#   'types',
#   'ideal',
#   'candidate',
#   'experienced',
#   'creating',
#   'analytics',
#   'data',
#   'stores',
#   'useful',
#   'deeper',
#   'analytics',
#   'data',
#   'modeling',
#   'well',
#   'data',
#   'transformations',
#   'role',
#   'must',
#   'able',
#   'work',
#   'collaboratively',
#   'fast',
#   'paced,',
#   'dynamic',
#   'environment',
#   'strong',
#   'interpersonal',
#   'communication',
#   'skills',
#   'position',
#   'based',
#   'atlanta',
#   'ga',
#   'responsibilities',
#   'performs',
#   'scientific',
#   'work',
#   'associated',
#   'analytical,',
#   'statistical,',
#   'programming',
#   'skills',
#   'collect,',
#   'analyze,',
#   'interpret',
#   'large',
#   'data',
#   'sets',
#   'develop',
#   'data_driven',
#   'solutions',
#   'difficult',
#   'business',
#   'challenges',
#   'knowledgeable',
#   'accessing',
#   'using',
#   'data',
#   'databases,',
#   'data',
#   'lakes,',
#   'data',
#   'warehouses,',
#   'operational',
#   'data',
#   'stores,',
#   'data',
#   'marts',
#   'assessment',
#   'alternative',
#   'data',
#   'science',
#   'solutions',
#   'approaches',
#   'support',
#   'mission',
#   'partners',
#   'building,',
#   'improving,',
#   'using',
#   'data',
#   'science',
#   'solutions',
#   'skills',
#   'experiencesrequired',
#   'bachelor’s',
#   'degree',
#   'computer',
#   'science,',
#   'information',
#   'systems,',
#   'another',
#   'related',
#   'field',
#   'two',
#   '2',
#   'years’',
#   'experience',
#   'data',
#   'analytics',
#   'visualization',
#   'tools',
#   'experience',
#   'predictive',
#   'analytics,',
#   'time_series',
#   'forecasting,',
#   'geospatial',
#   'analysis,',
#   'broader',
#   'data',
#   'science',
#   'tools',
#   'experience',
#   'statistical',
#   'analysis',
#   'experience',
#   'relational',
#   'databases',
#   'sql',
#   'experience',
#   'data',
#   'repositories',
#   'like',
#   'nosql,',
#   'hdfs,',
#   'mongodb',
#   'programming',
#   'skills',
#   'e',
#   'g',
#   'r,',
#   'python,',
#   'java,',
#   'scala',
#   'desired',
#   'master’s',
#   'degree',
#   'computer',
#   'science,',
#   'information',
#   'systems,',
#   'another',
#   'related',
#   'field',
#   'two',
#   '2',
#   'years’',
#   'experience',
#   'data',
#   'analytics',
#   'visualization',
#   'tools',
#   'etl',
#   'development',
#   'using',
#   'sql,',
#   'etl',
#   'tools,',
#   'programming',
#   'languages',
#   'familiarity',
#   'ai/ml',
#   '–',
#   'supervised',
#   'unsupervised',
#   'learning',
#   'familiarity',
#   'cloud_native',
#   'analytics',
#   'scheduled',
#   'weekly',
#   'hours',
#   '40',
#   'elecommuting',
#   'options',
#   'telecommuting',
#   'allowed',
#   'work',
#   'location',
#   'usa',
#   'ga',
#   'atlanta',
#   'additional',
#   'work',
#   'locations',
#   '50',
#   'years,',
#   'general',
#   'dynamics',
#   'information',
#   'technology',
#   'served',
#   'trusted',
#   'provider',
#   'information',
#   'technology,',
#   'systems',
#   'engineering,',
#   'training,',
#   'professional',
#   'services',
#   'customers',
#   'across',
#   'federal,',
#   'state,',
#   'local',
#   'governments,',
#   'commercial',
#   'sector',
#   '40,000',
#   'gdit',
#   'professionals',
#   'deliver',
#   'enterprise',
#   'solutions,',
#   'manage',
#   'mission_critical',
#   'programs,',
#   'provide',
#   'mission',
#   'support',
#   'services',
#   'worldwide',
#   'gdit',
#   'equal',
#   'opportunity/affirmative',
#   'action',
#   'employer',
#   'qualified',
#   'applicants',
#   'receive',
#   'consideration',
#   'employment',
#   'without',
#   'regard',
#   'race,',
#   'color,',
#   'religion,',
#   'sex,',
#   'sexual',
#   'orientation,',
#   'gender',
#   'identity,',
#   'national',
#   'origin,',
#   'disability,',
#   'veteran',
#   'status,',
#   'protected',
#   'class'],
#  ['job',
#   'description',
#   'data',
#   'scientist',
#   'prgx,',
#   'leading',
#   'team',
#   'business',
#   'analysts',
#   'technical',
#   'resources',
#   'solve',
#   'customers’',
#   'data',
#   'challenges',
#   'using',
#   'various',
#   'statistical,',
#   'modeling',
#   'machine',
#   'learning',
#   'techniques',
#   'data',
#   'scientist',
#   'able',
#   'individually',
#   'solve',
#   'problems',
#   'higher',
#   'complexity',
#   'assist',
#   'guide/mentor',
#   'junior',
#   'consultants',
#   'experience',
#   'problem',
#   'resolution',
#   'able',
#   'understand',
#   'business',
#   'problem',
#   'solved',
#   'skilled',
#   'extracting,',
#   'transforming,',
#   'analyzing',
#   'data',
#   'using',
#   'variety',
#   'common',
#   'analytical',
#   'tools',
#   'statistical',
#   'techniques',
#   'data',
#   'scientist',
#   'able',
#   'present',
#   'findings',
#   'compelling',
#   'manner',
#   'business',
#   'non_technical',
#   'audience',
#   'position',
#   'requires',
#   'team',
#   'player',
#   'seeks',
#   'supplement',
#   'skills',
#   'use',
#   'project',
#   'experience,',
#   'self_study,',
#   'ongoing',
#   'training',
#   'basic',
#   'qualifications',
#   '3+',
#   'years',
#   'professional',
#   'work',
#   'experience',
#   'working',
#   'data',
#   'integration,',
#   'classification',
#   'matching',
#   'machine',
#   'learning',
#   'data',
#   'science',
#   '3+',
#   'years',
#   'recent',
#   'hands_on',
#   'experience',
#   'working',
#   'data',
#   'tools',
#   'like',
#   'rapidminer,',
#   'alteryx',
#   'python',
#   'advanced',
#   'sql',
#   'skills',
#   'working',
#   'variety',
#   'databases',
#   'wrangling',
#   'cleansing',
#   'data',
#   'multiple',
#   'sources',
#   'minimum',
#   '2',
#   'years',
#   'experience',
#   'regression',
#   'techniques',
#   'logistic,',
#   'linear,',
#   'non_linear',
#   'data',
#   'classification',
#   'modeling',
#   'addition',
#   'modeling',
#   'techniques,',
#   'experience',
#   '2',
#   'additional',
#   'modeling',
#   'techniques',
#   'e',
#   'time',
#   'series',
#   'analysis,',
#   'text',
#   'analytics,',
#   'random',
#   'forest,',
#   'clustering,',
#   'linear',
#   'programming,',
#   'support',
#   'vector',
#   'machines,',
#   'naive',
#   'bayes,',
#   'neural',
#   'networks,',
#   'auto_encoders,',
#   'general',
#   'adversarial',
#   'networks,',
#   'principal',
#   'component',
#   'analysis,',
#   'markov',
#   'decision',
#   'process,',
#   'etc…',
#   'experience',
#   'working',
#   'directly',
#   'end',
#   'users',
#   'understand',
#   'business',
#   'problem',
#   'identifying',
#   'models',
#   'used',
#   'solve',
#   'problem',
#   'prior',
#   'experience',
#   'mentoring',
#   'leading',
#   'teams',
#   'junior',
#   'data',
#   'scientists',
#   'business',
#   'analysts',
#   'responsible',
#   'providing',
#   'project',
#   'estimates',
#   'work',
#   'stream',
#   'assigning',
#   'tasks',
#   'team',
#   'members',
#   'excellent',
#   'written',
#   'oral',
#   'communication',
#   'skills',
#   'must',
#   'capable',
#   'effectively',
#   'articulating',
#   'technical',
#   'concepts',
#   'non_technical',
#   'audiences',
#   'must',
#   'undergraduate',
#   'bs',
#   'postgraduate',
#   'ms/ph',
#   'degree',
#   'statistics,',
#   'mathematics,',
#   'physics,',
#   'econometrics,',
#   'operations',
#   'research',
#   'equivalent',
#   'work',
#   'experience',
#   'minimum',
#   '5',
#   'years',
#   'professional',
#   'work',
#   'experience',
#   'nice',
#   'experience',
#   'working',
#   '1',
#   'data',
#   'visualization',
#   'tools',
#   'qlik',
#   'sense,',
#   'tableau',
#   'powerbi',
#   'tell',
#   '“data”',
#   'story',
#   'individuals',
#   'past',
#   'management',
#   'consulting',
#   'experience'],
#  ['dematic',
#   'leading',
#   'supplier',
#   'integrated',
#   'automated',
#   'technology,',
#   'software',
#   'services',
#   'optimize',
#   'supply',
#   'chain',
#   'dematic',
#   'employs',
#   '7,000',
#   'skilled',
#   'logistics',
#   'professionals',
#   'serve',
#   'customers',
#   'globally,',
#   'engineering',
#   'centers',
#   'manufacturing',
#   'facilities',
#   'located',
#   'around',
#   'world',
#   'dematic',
#   'one',
#   'brand',
#   'kion',
#   'group',
#   'companies',
#   'implemented',
#   '6,000',
#   'integrated',
#   'systems',
#   'customer',
#   'base',
#   'includes',
#   'small,',
#   'medium',
#   'large',
#   'companies',
#   'business',
#   'variety',
#   'market',
#   'sectors',
#   'headquartered',
#   'atlanta,',
#   'georgia,',
#   'dematic',
#   'member',
#   'kion',
#   'group,',
#   'global',
#   'leader',
#   'industrial',
#   'trucks,',
#   'related',
#   'services',
#   'supply',
#   'chain',
#   'solutions',
#   'across',
#   '100',
#   'countries',
#   'worldwide,',
#   'kion',
#   'group',
#   'designs,',
#   'builds',
#   'supports',
#   'logistics',
#   'solutions',
#   'optimize',
#   'material',
#   'information',
#   'flow',
#   'within',
#   'factories,',
#   'warehouses',
#   'distribution',
#   'centers',
#   'company',
#   'largest',
#   'manufacturer',
#   'industrial',
#   'trucks',
#   'europe,',
#   'second_largest',
#   'producer',
#   'forklifts',
#   'globally',
#   'leading',
#   'provider',
#   'warehouse',
#   'automation',
#   'role',
#   'position',
#   'summary',
#   'exciting',
#   'opportunity',
#   'join',
#   'software',
#   'center',
#   'excellence',
#   'dematic',
#   'part',
#   'global',
#   'team',
#   'software',
#   'experts,',
#   'help',
#   'develop',
#   'robust',
#   'organizational',
#   'capabilities',
#   'sales,',
#   'design,',
#   'engineering',
#   'support',
#   'deliver',
#   'exceptional',
#   'software',
#   'customers',
#   'specialist,',
#   'end_to_end',
#   'implementation',
#   'analytics',
#   'iot',
#   'engagements',
#   'dematic',
#   'customers,',
#   'driving',
#   'services',
#   'pipeline',
#   'well',
#   'key',
#   'voice',
#   'internally',
#   'development',
#   'analytics',
#   'services',
#   'program',
#   'cross_functional',
#   'role',
#   'within',
#   'organization',
#   'well',
#   'key',
#   'customer',
#   'interfacing',
#   'role',
#   'successful',
#   'candidate',
#   'demonstrated',
#   'exceptional',
#   'performance,',
#   'innovation,',
#   'creativity',
#   'insight',
#   'similar',
#   'role',
#   'key',
#   'responsibilities',
#   'problem',
#   'solving,',
#   'critical',
#   'thinking',
#   'works',
#   'customer',
#   'end_users',
#   'define',
#   'analytics',
#   'iot',
#   'solution',
#   'requirements',
#   'works',
#   'internal',
#   'team',
#   'concept,',
#   'design',
#   'deliver',
#   'solution',
#   'works',
#   'independently,',
#   'within',
#   'teams,',
#   'multiple',
#   'types',
#   'skillsets',
#   'business,',
#   'data',
#   'architect,',
#   'technical',
#   'resources',
#   'performs',
#   'business',
#   'process',
#   'analysis,',
#   'mapping',
#   'design',
#   'ensures',
#   'high',
#   'quality',
#   'delivery',
#   'software',
#   'consulting',
#   'services',
#   'overall',
#   'client',
#   'satisfaction',
#   'drives',
#   'development',
#   'documentation',
#   'services',
#   'displays',
#   'depth',
#   'knowledge',
#   'customers',
#   'sales_phase',
#   'representing',
#   'breadth',
#   'depth',
#   'dematic',
#   'solutions',
#   'expertise',
#   'supports',
#   'sales',
#   'organization',
#   'drive',
#   'pipeline',
#   'generation',
#   'analytics',
#   'consulting',
#   'services',
#   'education',
#   "bachelor's",
#   'degree',
#   'and/or',
#   'advanced',
#   'degree',
#   'knowledge',
#   'qualifications',
#   'qualifications',
#   'position',
#   'advanced',
#   'analytics',
#   'iot',
#   'proven',
#   'success',
#   'client',
#   'management,',
#   'project',
#   'management,',
#   'consultative',
#   'selling',
#   'services',
#   'delivery',
#   'important',
#   'areas',
#   'experience',
#   'skills',
#   'experience',
#   'working',
#   'business',
#   'users',
#   'concept,',
#   'generate',
#   'deliver',
#   'analytics',
#   'solutions,',
#   'dashboards',
#   'reporting',
#   'overall',
#   'knowledge',
#   'mhe',
#   'technologies',
#   'warehouse',
#   'systems',
#   'similar',
#   'domains',
#   'preferred',
#   'specific',
#   'domain',
#   'experience',
#   'knowledge',
#   'logistics',
#   'supply',
#   'chain',
#   'industries',
#   'plus',
#   'excellent',
#   'written',
#   'verbal',
#   'communication',
#   'skills',
#   'including',
#   'presentation',
#   'skills',
#   'knowledge',
#   'software',
#   'tools',
#   'ms',
#   'powerpoint,',
#   'ms',
#   'visio',
#   'strong',
#   'leadership',
#   'customer',
#   'engagement',
#   'skills',
#   'willingness',
#   'travel',
#   'order',
#   'satisfy',
#   'client',
#   'needs',
#   'experience',
#   'conducting',
#   'requirements',
#   'analysis,',
#   'meeting',
#   'business',
#   'stakeholders',
#   'applying',
#   'solutions',
#   'customer',
#   'challenges',
#   'working',
#   'knowledge',
#   'advanced',
#   'analytic',
#   'tools',
#   'sas,',
#   'r,',
#   'python',
#   'required',
#   'working',
#   'knowledge',
#   'data',
#   'visualization',
#   'tools',
#   'tableau,',
#   'qlikview,',
#   'domo',
#   'required',
#   'working',
#   'knowledge',
#   'bi',
#   'business',
#   'intelligence',
#   'analytics',
#   'tools',
#   'preferred',
#   'working',
#   'knowledge',
#   'microsoft',
#   'sql',
#   'server',
#   'and/or',
#   'oracle',
#   'databases',
#   'preferred',
#   'working',
#   'knowledge',
#   'cloud',
#   'based',
#   'technologies',
#   'preferred',
#   'least',
#   '3',
#   'years',
#   'experience',
#   'related',
#   'role'],
#  ['hd',
#   'supply',
#   'nasdaq',
#   'hds',
#   'www',
#   'hdsupply',
#   'com',
#   'one',
#   'largest',
#   'industrial',
#   'distributors',
#   'north',
#   'america',
#   'company',
#   'provides',
#   'broad',
#   'range',
#   'products',
#   'value_add',
#   'services',
#   'approximately',
#   '500,000',
#   'customers',
#   'leadership',
#   'positions',
#   'maintenance,',
#   'repair',
#   'operations',
#   'specialty',
#   'construction',
#   'sectors',
#   'approximately',
#   '260',
#   'locations',
#   'across',
#   '36',
#   'states',
#   'six',
#   'canadian',
#   'provinces,',
#   "company's",
#   'approximately',
#   '11,000',
#   'associates',
#   'provide',
#   'localized,',
#   'customer_driven',
#   'services',
#   'including',
#   'jobsite',
#   'delivery,',
#   'call',
#   'direct_ship',
#   'options,',
#   'diversified',
#   'logistics',
#   'innovative',
#   'solutions',
#   'contribute',
#   "customers'",
#   'success',
#   'active',
#   'commitment',
#   'communities',
#   'operate,',
#   'hd',
#   'supply',
#   'associates',
#   'part',
#   'thriving',
#   'organization',
#   'supports',
#   'virtues',
#   'wellness,',
#   'diversity',
#   'inclusion',
#   '–',
#   'top',
#   'priorities',
#   'company',
#   'equally',
#   'important',
#   'empowering',
#   'associates',
#   'grow',
#   'professionally',
#   'providing',
#   'competitive',
#   'benefits',
#   'compensation',
#   'you’re',
#   'ready',
#   'find',
#   'rewarding',
#   'career',
#   'achieve',
#   'full',
#   'potential',
#   'growing',
#   'industry',
#   'leader,',
#   'hd',
#   'supply',
#   'ready',
#   'job',
#   'su',
#   'mmary',
#   'responsible',
#   'modeling',
#   'complex',
#   'enterprise',
#   'problems,',
#   'discovering',
#   'enterprise',
#   'insights,',
#   'identifying',
#   'opportunities',
#   'use',
#   'statistical',
#   'machine',
#   'learning',
#   'algorithms,',
#   'data',
#   'mining,',
#   'visualization',
#   'techniques',
#   'integrates',
#   'prepares',
#   'varied',
#   'datasets,',
#   'architects',
#   'custom',
#   'data',
#   'environments,',
#   'communicates',
#   'validation',
#   'results',
#   'major',
#   'tasks,',
#   'responsibilities',
#   'key',
#   'accountabilities',
#   'leads',
#   'discovery',
#   'processes',
#   'key',
#   'stakeholders',
#   'identify',
#   'business',
#   'requirements',
#   'expected',
#   'outcomes',
#   'makes',
#   'strategic',
#   'recommendations',
#   'data',
#   'collection,',
#   'integration',
#   'retention,',
#   'business',
#   'requirements,',
#   'knowledge',
#   'best',
#   'practices',
#   'develops',
#   'innovative',
#   'effective',
#   'approaches',
#   'solve',
#   'analytics',
#   'problems',
#   'communicates',
#   'results',
#   'methodologies',
#   'collaborates',
#   'subject',
#   'matter',
#   'experts',
#   'regarding',
#   'relevant',
#   'sources',
#   'information',
#   'makes',
#   'recommendations',
#   'data',
#   'collection,',
#   'integration,',
#   'retention',
#   'requirements',
#   'recommends',
#   'new',
#   'improved',
#   'methods',
#   'improve',
#   'data',
#   'search',
#   'quality',
#   'predictive',
#   'prescriptive',
#   'capabilities',
#   'integrates',
#   'prepares',
#   'large,',
#   'varied',
#   'datasets',
#   'architects',
#   'specialized',
#   'database',
#   'computing',
#   'environments',
#   'communicates',
#   'results',
#   'creates',
#   'statistical',
#   'machine',
#   'learning',
#   'models',
#   'solve',
#   'complex',
#   'business',
#   'problems',
#   'across',
#   'sales,',
#   'marketing,',
#   'supply',
#   'chain',
#   'partners',
#   'data',
#   'engineers',
#   'information',
#   'technology',
#   'operationalize',
#   'machine',
#   'learning',
#   'algorithms',
#   'production',
#   'environment',
#   'nature',
#   'scope',
#   'identifies',
#   'key',
#   'barriers/core',
#   'problems',
#   'applies',
#   'problem',
#   'solving',
#   'skills',
#   'order',
#   'deal',
#   'creatively',
#   'complex',
#   'situations',
#   'troubleshoots',
#   'resolves',
#   'complex',
#   'problems',
#   'makes',
#   'decisions',
#   'conditions',
#   'uncertainty,',
#   'sometimes',
#   'incomplete',
#   'information,',
#   'produce',
#   'effective',
#   'end',
#   'results',
#   'independently',
#   'performs',
#   'assignments',
#   'instruction',
#   'limited',
#   'expected',
#   'results',
#   'determines',
#   'develops',
#   'approach',
#   'solutions',
#   'receives',
#   'technical',
#   'guidance',
#   'unusual',
#   'complex',
#   'problems',
#   'issues',
#   'may',
#   'oversee',
#   'completion',
#   'projects',
#   'assignments,',
#   'including',
#   'planning,',
#   'assigning,',
#   'monitoring',
#   'reviewing',
#   'progress',
#   'accuracy',
#   'work,',
#   'evaluating',
#   'results,',
#   'etc',
#   'contributes',
#   "employees'",
#   'professional',
#   'development',
#   'hiring',
#   'firing',
#   'authority',
#   'work',
#   'environment',
#   'located',
#   'comfortable',
#   'indoor',
#   'area',
#   'unpleasant',
#   'conditions',
#   'would',
#   'infrequent',
#   'objectionable',
#   'time',
#   'spent',
#   'sitting',
#   'comfortable',
#   'position',
#   'frequent',
#   'opportunity',
#   'move',
#   'rare',
#   'occasions',
#   'may',
#   'move',
#   'lift',
#   'light',
#   'articles',
#   'typically',
#   'requires',
#   'overnight',
#   'travel',
#   'less',
#   '10',
#   'time',
#   'education',
#   'experience',
#   'typically',
#   'requires',
#   'bs/ba',
#   'related',
#   'discipline',
#   'generally',
#   '5_8',
#   'years',
#   'experience',
#   'related',
#   'field',
#   'ms/ma',
#   'generally',
#   '3_5',
#   'years',
#   'experience',
#   'related',
#   'field',
#   'certification',
#   'required',
#   'areas',
#   'preferred',
#   'qualifications',
#   '2_3',
#   'years',
#   'experience',
#   'field',
#   'retail',
#   'marketing',
#   'operational',
#   'related',
#   'applied',
#   'data',
#   'science',
#   '3+',
#   'years',
#   'relevant',
#   'quantitative',
#   'analytics',
#   'experience',
#   'equivalent',
#   'educational',
#   'experience',
#   'masters’s',
#   'degree',
#   'mathematics,',
#   'statistics',
#   'computer',
#   'science',
#   'related',
#   'field',
#   'preferred',
#   'strong',
#   'understanding',
#   'application',
#   'statistical',
#   'methods',
#   'skills',
#   'distributions,',
#   'experimental',
#   'design,',
#   'variance',
#   'analysis,',
#   'a/b',
#   'testing,',
#   'glm/',
#   'regression',
#   'expertise',
#   'machine',
#   'learning',
#   'algorithms',
#   'experience',
#   'using',
#   'following',
#   'ml',
#   'techniques',
#   'logistic',
#   'regression,',
#   'decision',
#   'trees,',
#   'random',
#   'forests,',
#   'gradient',
#   'boosting,',
#   'svms,',
#   'time',
#   'series,',
#   'kmeans,',
#   'clustering,',
#   'recommendation',
#   'systems',
#   'strong',
#   'coding',
#   'debugging',
#   'skills',
#   'one',
#   'following',
#   'technologies',
#   'python,',
#   'r,',
#   'scikit_learn,',
#   'h2o,',
#   'azure',
#   'advanced',
#   'knowledge',
#   'sql',
#   'proven',
#   'experience',
#   'large',
#   'data',
#   'sets',
#   'hadoop,',
#   'hive,',
#   'spark',
#   'strong',
#   'skills',
#   'developing',
#   'recommendation',
#   'engines',
#   'collaborative',
#   'filtering',
#   'developing',
#   'models',
#   'supply',
#   'chain',
#   'optimization',
#   'plus',
#   'experience',
#   'visualizing/presenting',
#   'data',
#   'stakeholders',
#   'using',
#   'following',
#   'tableau,',
#   'powerbi,',
#   'ggplot,',
#   'etc',
#   'must',
#   'proven',
#   'track',
#   'record',
#   'partnering',
#   'business',
#   'delivering',
#   'quality',
#   'business',
#   'solutions',
#   'strong',
#   'collaboration',
#   'skills',
#   'technical',
#   'non_technical',
#   'groups',
#   'prid142'],
#  ['data',
#   'scientist',
#   'location',
#   'atlanta',
#   'usa',
#   'demand',
#   'sensing,',
#   'om',
#   'partners',
#   'breaking',
#   'boundaries',
#   'classical',
#   'demand',
#   'forecasting',
#   'use',
#   'state',
#   'art',
#   'techniques',
#   'like',
#   'machine',
#   'learning',
#   'neural',
#   'networks',
#   'allow',
#   'step',
#   'change',
#   'forecast',
#   'accuracy,',
#   'driving',
#   'immediate',
#   'value',
#   'creation',
#   'customers',
#   'using',
#   'innovative',
#   'functionalities,',
#   'able',
#   'adjust',
#   'supply',
#   'plans',
#   'faster',
#   'accurate',
#   'ready',
#   'join',
#   'demand',
#   'driven',
#   'revolution',
#   'supply',
#   'chain',
#   'passionate',
#   'finding',
#   'patterns',
#   'correlations',
#   'apply',
#   'position',
#   'senior',
#   'data',
#   'scientist',
#   'join',
#   'product',
#   'development',
#   'team',
#   'challenge',
#   'data',
#   'scientist,',
#   'one',
#   'aim',
#   'provide',
#   'innovative',
#   'solutions',
#   'customers’',
#   'challenging',
#   'analytics',
#   'forecasting',
#   'needs',
#   'analyze',
#   'needs,',
#   'design',
#   'prototype,',
#   'develop',
#   'model',
#   'optimize',
#   'solution',
#   'support',
#   'customer',
#   'throughout',
#   'entire',
#   'implementation',
#   'schedule',
#   'work',
#   'close',
#   'collaboration',
#   'customer’s',
#   'project',
#   'team',
#   'consultant',
#   'colleagues',
#   'working',
#   'project',
#   'next',
#   'project',
#   'work',
#   'responsible',
#   'design',
#   'solutions',
#   'development',
#   'products',
#   'ensure',
#   'high_quality,',
#   'well_tested',
#   'documented',
#   'solutions',
#   'delivered',
#   'challenge',
#   'collect',
#   'formulate',
#   'business',
#   'requirements',
#   'translate',
#   'functional',
#   'requirements',
#   'easily',
#   'fed',
#   'technical',
#   'design',
#   'therefore,',
#   'work',
#   'close',
#   'collaboration',
#   'product',
#   'manager',
#   'software',
#   'engineers',
#   'continuously',
#   'improve',
#   'solutions',
#   'develop',
#   'new',
#   'functionalities',
#   'validate',
#   'solutions',
#   'functionalities',
#   'different',
#   'stakeholders',
#   'implement',
#   'test',
#   'developments',
#   'finally,',
#   'document',
#   'tools,',
#   'train',
#   'support',
#   'colleagues',
#   'usage',
#   'solution',
#   'participate',
#   'pre_sales',
#   'demonstrate',
#   'functionality',
#   'meets',
#   'prospects',
#   'goals',
#   'objectives',
#   'profile',
#   'strong',
#   'analytical',
#   'skills',
#   'problem',
#   'solving',
#   'abilities,',
#   'complemented',
#   'university',
#   'degree,',
#   'indispensable',
#   'job',
#   'phd',
#   'definite',
#   'advantage',
#   'entrepreneurial',
#   'mindset',
#   'innovative',
#   'solutions',
#   'customers’',
#   'analytics',
#   'forecasting',
#   'problems',
#   'passionate',
#   'finding',
#   'patterns',
#   'correlations',
#   'big',
#   'datasets',
#   'take',
#   'incomplete',
#   'data',
#   'challenge',
#   'use',
#   'qualitative',
#   'techniques',
#   'bridge',
#   'gap',
#   'solid',
#   'background',
#   'applied',
#   'statistics',
#   'distributions,',
#   'statistical',
#   'testing,',
#   'confidence',
#   'intervals,',
#   'machine',
#   'learning,',
#   'time',
#   'series,',
#   '…',
#   'required',
#   'practical',
#   'experience',
#   'time',
#   'series',
#   'analysis',
#   'forecasting',
#   'exponential',
#   'smoothing,',
#   'multivariate',
#   'regression,',
#   'arima,',
#   '…',
#   'solve',
#   'real_life',
#   'business',
#   'problems',
#   'benefit',
#   'experience',
#   'analyzing',
#   'implementing',
#   'forecasting',
#   'processes,',
#   'well',
#   'working',
#   'experience',
#   'analyst',
#   'consultant',
#   'large',
#   'multinational',
#   'organizations',
#   'familiar',
#   'statistical',
#   'scripting',
#   'language,',
#   'preferably',
#   'r',
#   'basic',
#   'knowledge',
#   'relational',
#   'databases',
#   'sql',
#   'plus',
#   'present',
#   'findings',
#   'clearly',
#   'non_technical',
#   'audience,',
#   'using',
#   'different',
#   'visualization',
#   'techniques',
#   'excellent',
#   'command',
#   'least',
#   'two',
#   'languages',
#   'dutch,',
#   'french,',
#   'english',
#   'german',
#   'able',
#   'work',
#   'autonomous',
#   'project',
#   'based',
#   'company',
#   'om',
#   'partners',
#   'software',
#   'consulting',
#   'company',
#   'focused',
#   'supply',
#   'chain',
#   'planning',
#   'company',
#   'one',
#   'mission',
#   'optimize',
#   'customer’s',
#   'supply',
#   'chain',
#   'pride',
#   'developing',
#   'innovative',
#   'advanced',
#   'planning',
#   'systems',
#   'aps',
#   'meet',
#   'exceed',
#   'expectations',
#   'customer',
#   'base',
#   'includes',
#   'leading',
#   'companies',
#   'different',
#   'industries,',
#   'arcelormittal,',
#   'basf,',
#   'dow,',
#   'johnson',
#   'johnson,',
#   'michelin,',
#   'shaw,',
#   'procter',
#   'gamble',
#   'smurfit',
#   'kappa',
#   'growing',
#   'international',
#   'company',
#   'lots',
#   'opportunities',
#   'people',
#   'work',
#   'offices',
#   'belgium,',
#   'netherlands,',
#   'france,',
#   'germany,',
#   'uk,',
#   'usa,',
#   'china,',
#   'brazil,',
#   'ukraine,',
#   'uae',
#   'india',
#   'respect,',
#   'team',
#   'spirit',
#   'creativity',
#   'cornerstones',
#   'working',
#   'culture',
#   'right',
#   'person',
#   'challenge']]

# %%
bigram = Phrases(sentences = descriptions, min_count=1, threshold=1, max_vocab_size=5000)
phrased_descriptions = [bigram[d] for d in descriptions]
df_filteredbyloc['phrased_descriptions'] = phrased_descriptions
df_filteredbyloc['cleaned_phrased_descriptions'] = [' '.join(d) for d in df_filteredbyloc.phrased_descriptions]

# %%
df_filteredbyloc['phrased_descriptions'].head()
# Out:
# 0    [sr, data, scientist, sr, data, scientist, dri...
# 1    [position, summary, data, scientist, provides,...
# 2    [team, hits, game, winner, band, plays, favori...
# 3    [purpose, position, inspire, data, scientist, ...
# 4    [atlanta,, georgia, skills, python, ,r, ,scala...
# Name: phrased_descriptions, dtype: object

# %%
df_filteredbyloc['cleaned_phrased_descriptions'][0]
# Out:
# "sr data scientist sr data scientist driven interest solving complex problems data exploration analysis highly analytically minded robust technical tool kit substantial experience analytics portfolio successfully executed models sr data scientist responsible executing steps modeling process produce high quality, reproducible results work team analyst support development processes technologies improve patient outcomes role responsible extracting, managing, analyzing complex administrative healthcare data applying client/ai concepts uncover opportunities process improvement responsibilities develop algorithms applications apply mathematics data, perform large_scale experimentation develop functionality work large_scale real_world health data evidence generation drive innovation via use data driven insights customers biggest problems build advocate data_driven solutions help customers improve clinical outcomes processes design build scalable production_ready analytics solutions using wide array techniques methodologies field statistical modeling, machine_learning, ai technologies meet needs given client engagements design develop deep learning, machine_learning, data mining, r, python, statistical models, data analysis techniques collect, explore, extract insights structured unstructured electronic health record data create dashboards presentations communicate analytic findings requirements minimum bachelor's_degree computer_science, engineering, physics, highly quantitative technically oriented field, master's degree preferred 5+ years professional work experience quantitative analyst applied analytics technical leader healthcare experience preferred mastery statistical software, scripting languages, packages_ preferred r, python, sql prior experience natural language processing using nltk sql knowledge experience working relational databases, query authoring sql well working familiarity variety databases/date_sources solid understanding data structures, software design architecture ability work independently take initiative, also co_operative team player proficient interpreting business questions applying concepts data"

# %%
y = df_filteredbyloc['job_cat']
X = df_filteredbyloc['cleaned_phrased_descriptions']

# %%
#vectorize data
count_vectorizer = CountVectorizer()
tfidf_vectorizer = TfidfVectorizer()

X_t = tfidf_vectorizer.fit_transform(X)

# %%
X_t.shape
# Out:
# (1175, 15311)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    random_state=0)

# %%
# for non-pipeline model
X_train_np, X_test_np, y_train_np, y_test_np = train_test_split(X_t.toarray(), y, test_size=0.2,
                                                    random_state=0)

# %%
X_train[:3]
# Out:
# 1092    design, develop, troubleshoot debug software p...
# 453     founded 2014, octane lending fintech startup v...
# 892     focus data science team digitizing recruiting ...
# Name: cleaned_phrased_descriptions, dtype: object

# %% [markdown]
# SCRUB

# %%
df_filteredbyloc.sum().isna()
# Out:
# index                           False
# company                         False
# description                     False
# job_cat                         False
# loc                             False
# position                        False
# descriptions                    False
# phrased_descriptions            False
# cleaned_phrased_descriptions    False
# dtype: bool

# %% [markdown]
# EXPLORE

# %%
df_filteredbyloc.groupby('loc').count()
# Out:
#       index  company  description  job_cat  position  descriptions  \
# loc
# ATL     282      282          282      282       282           282
# KCMO     96       96           96       96        96            96
# NY      797      797          797      797       797           797
#
#       phrased_descriptions  cleaned_phrased_descriptions
# loc
# ATL                    282                           282
# KCMO                    96                            96
# NY                     797                           797

# %% [markdown]
# MODEL

# %%
#library imnports - model
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB

# %%
len(tfidf_vectorizer.get_feature_names())
# Out:
# 15311

# %%
#classification model pipelines
pipelines = {
    'multinomialnb': make_pipeline(TfidfVectorizer(), MultinomialNB()),
    'logisticregression': make_pipeline(TfidfVectorizer(), LogisticRegression()),
    'randomforestclassifier': make_pipeline(TfidfVectorizer(), RandomForestClassifier()),
    'gradientboostingclassifier': make_pipeline(TfidfVectorizer(), GradientBoostingClassifier())
}
#define hyperparameters for each model 
multinomialnb_hyperparameters = {
    'multinomialnb__alpha': np.linspace(0.5, 1.5, 6),
    'multinomialnb__fit_prior': [True, False]
}
logisticregression_hyperparameters = {
    'logisticregression__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]
}
randomforestclassifier_hyperparameters = {
    'randomforestclassifier__n_estimators': [100, 200], 
    'randomforestclassifier__max_features': ['auto', 'sqrt',0.33]
}
gradientboostingclassifier_hyperparameters = {
    'gradientboostingclassifier__n_estimators': [100, 200], 
    'gradientboostingclassifier__learning_rate': [0.05, 0.1, 0.2],
    'gradientboostingclassifier__max_depth': [1, 3, 5]
}
#set hyperparameter dictionary
hyperparameters = {
    'multinomialnb': multinomialnb_hyperparameters,
    'logisticregression': logisticregression_hyperparameters,
    'randomforestclassifier': randomforestclassifier_hyperparameters,
    'gradientboostingclassifier': gradientboostingclassifier_hyperparameters
}

# %%
fitted_models = {}

for name, pipeline in pipelines.items():
    model = GridSearchCV(pipeline, hyperparameters[name], cv=10, n_jobs=-1, scoring='roc_auc')
    model.fit(X_train, y_train)
    y_hat = model.predict(X_test)
    confusion_matrix(y_hat, y_test)
    fitted_models[name] = model
    print(name, 'has been fitted.')

for name, model in fitted_models.items(): 
    print(name, model.best_score_)
    y_hat = model.predict(X_test)
    confusion_matrix(y_hat, y_test)
# Out:
# multinomialnb has been fitted.
# /Users/blewis2/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# logisticregression has been fitted.
# randomforestclassifier has been fitted.
# gradientboostingclassifier has been fitted.
# multinomialnb 0.9639052325801897
# logisticregression 0.9830256500153026
# randomforestclassifier 0.9898190450801345
# gradientboostingclassifier 0.9902678678686624

# %%
for name, model in fitted_models.items(): 
    print(name, model.best_score_)
    y_hat = model.predict(X_test)
    print(confusion_matrix(y_hat, y_test))
    print(classification_report(y_hat, y_test))
# Out:
# multinomialnb 0.9639052325801897
# [[ 71   2]
#  [ 35 127]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.67      0.97      0.79        73
# data scientist       0.98      0.78      0.87       162
#
#      micro avg       0.84      0.84      0.84       235
#      macro avg       0.83      0.88      0.83       235
#   weighted avg       0.89      0.84      0.85       235
#
# logisticregression 0.9830256500153026
# [[101   7]
#  [  5 122]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.95      0.94      0.94       108
# data scientist       0.95      0.96      0.95       127
#
#      micro avg       0.95      0.95      0.95       235
#      macro avg       0.95      0.95      0.95       235
#   weighted avg       0.95      0.95      0.95       235
#
# randomforestclassifier 0.9898190450801345
# [[ 99   1]
#  [  7 128]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.93      0.99      0.96       100
# data scientist       0.99      0.95      0.97       135
#
#      micro avg       0.97      0.97      0.97       235
#      macro avg       0.96      0.97      0.97       235
#   weighted avg       0.97      0.97      0.97       235
#
# gradientboostingclassifier 0.9902678678686624
# [[ 98   1]
#  [  8 128]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.92      0.99      0.96        99
# data scientist       0.99      0.94      0.97       136
#
#      micro avg       0.96      0.96      0.96       235
#      macro avg       0.96      0.97      0.96       235
#   weighted avg       0.96      0.96      0.96       235

# %%
fitted_models['randomforestclassifier']

# %%
fitted_models['randomforestclassifier'].best_params_

# %%
# Save classifier to a file
import pickle 

save_classifier = open("Tfidf_randomforestclassifier.pickle", 'wb') #wb= write in bytes. 
pickle.dump(fitted_models['randomforestclassifier'], save_classifier) #use pickle to dump the grid3 we trained, as 'Tfidf_LogR.pickle' in wb format
save_classifier.close()

# %%
randomforestclassifier = fitted_models['randomforestclassifier']

# %%
# Retrieve the saved file and uplaod it to an object

model_randomforestclassifier = open("Tfidf_randomforestclassifier.pickle", 'rb') # rb= read in bytes
grid = pickle.load(model_randomforestclassifier)
model_randomforestclassifier.close()

# %%
# non-pipeline rf_classifier for convenience
clf = RandomForestClassifier(max_features=0.33, n_estimators=100, random_state=0)
clf.fit(X_train_np, y_train_np)
y_hat_np = clf.predict(X_test_np)
print(confusion_matrix(y_hat_np, y_test_np))
print(classification_report(y_hat_np, y_test_np))
# Out:
# [[ 99   1]
#  [  7 128]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.93      0.99      0.96       100
# data scientist       0.99      0.95      0.97       135
#
#      micro avg       0.97      0.97      0.97       235
#      macro avg       0.96      0.97      0.97       235
#   weighted avg       0.97      0.97      0.97       235

# %% [markdown]
# ### Run model with 'data scientist' and 'data analyst' added to stopwords

# %%
descriptions_2 = df_filteredbyloc.description 
descriptions_2 = [cleaner(d, stopwords=stopword_set_titles) for d in descriptions_2]
df_filteredbyloc['descriptions_2'] = descriptions_2

# %%
bigram = Phrases(sentences = descriptions_2, min_count=1, threshold=1, max_vocab_size=5000)
phrased_descriptions_2 = [bigram[d] for d in descriptions_2]
df_filteredbyloc['phrased_descriptions_2'] = phrased_descriptions_2
df_filteredbyloc['cleaned_phrased_descriptions_2'] = [' '.join(d) for d in df_filteredbyloc.phrased_descriptions_2]

# %%
y_2 = df_filteredbyloc['job_cat']
X_2 = df_filteredbyloc['cleaned_phrased_descriptions_2']

X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_2, y_2, test_size=0.2,
                                                    random_state=0)

# %%
fitted_models_2 = {}

for name, pipeline in pipelines.items():
    model = GridSearchCV(pipeline, hyperparameters[name], cv=10, n_jobs=-1, scoring='roc_auc')
    model.fit(X_train_2, y_train_2)
    y_hat_2 = model.predict(X_test_2)
    confusion_matrix(y_hat_2, y_test_2)
    fitted_models_2[name] = model
    print(name, 'has been fitted.')

for name, model in fitted_models_2.items(): 
    print(name, model.best_score_)
    y_hat = model.predict(X_test_2)
    confusion_matrix(y_hat_2, y_test_2)
# Out:
# multinomialnb has been fitted.
# /Users/blewis2/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# logisticregression has been fitted.
# randomforestclassifier has been fitted.
# gradientboostingclassifier has been fitted.
# multinomialnb 0.9639052325801897
# logisticregression 0.9830256500153026
# randomforestclassifier 0.9899692028266481
# gradientboostingclassifier 0.9900376567432334

# %%
for name, model in fitted_models_2.items(): 
    print(name, model.best_score_)
    y_hat_2 = model.predict(X_test_2)
    print(confusion_matrix(y_hat_2, y_test_2))
    print(classification_report(y_hat_2, y_test_2))
# Out:
# multinomialnb 0.9639052325801897
# [[ 71   2]
#  [ 35 127]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.67      0.97      0.79        73
# data scientist       0.98      0.78      0.87       162
#
#      micro avg       0.84      0.84      0.84       235
#      macro avg       0.83      0.88      0.83       235
#   weighted avg       0.89      0.84      0.85       235
#
# logisticregression 0.9830256500153026
# [[101   7]
#  [  5 122]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.95      0.94      0.94       108
# data scientist       0.95      0.96      0.95       127
#
#      micro avg       0.95      0.95      0.95       235
#      macro avg       0.95      0.95      0.95       235
#   weighted avg       0.95      0.95      0.95       235
#
# randomforestclassifier 0.9899692028266481
# [[100   1]
#  [  6 128]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.94      0.99      0.97       101
# data scientist       0.99      0.96      0.97       134
#
#      micro avg       0.97      0.97      0.97       235
#      macro avg       0.97      0.97      0.97       235
#   weighted avg       0.97      0.97      0.97       235
#
# gradientboostingclassifier 0.9900376567432334
# [[ 98   2]
#  [  8 127]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.92      0.98      0.95       100
# data scientist       0.98      0.94      0.96       135
#
#      micro avg       0.96      0.96      0.96       235
#      macro avg       0.95      0.96      0.96       235
#   weighted avg       0.96      0.96      0.96       235

# %%
X_t_2 = tfidf_vectorizer.fit_transform(X_2)

# %%
# for non-pipeline model with ds/da added to stopwords
X_train_2_np, X_test_2_np, y_train_2_np, y_test_2_np = train_test_split(X_t_2.toarray(), y_2, test_size=0.2,
                                                    random_state=0)

# %%
# non-pipeline rf_classifier with ds/da added to stopwords for convenience
clf_2 = RandomForestClassifier(max_features=0.33, n_estimators=100, random_state=0)
clf_2.fit(X_train_2_np, y_train_2_np)
y_hat_2_np = clf.predict(X_test_2_np)
print(confusion_matrix(y_hat_2_np, y_test_2_np))
print(classification_report(y_hat_2_np, y_test_2_np))
# Out:
# [[ 99   1]
#  [  7 128]]
#                 precision    recall  f1-score   support
#
#   data analyst       0.93      0.99      0.96       100
# data scientist       0.99      0.95      0.97       135
#
#      micro avg       0.97      0.97      0.97       235
#      macro avg       0.96      0.97      0.97       235
#   weighted avg       0.97      0.97      0.97       235

# %% [markdown]
# ## Extracting Feature Importances of Each Class

# %%
y.value_counts()
# Out:
# data scientist    633
# data analyst      542
# Name: job_cat, dtype: int64

# %%
top_10 = clf.feature_importances_.argsort()[-10:]

# %%
for index in top_10:
    print(tfidf_vectorizer.get_feature_names()[index])
# Out:
# reporting
# models
# algorithms
# reports
# excel
# science
# python
# machine_learning
# analyst
# scientist

# %%
sorted(clf.feature_importances_)[-10:]
# Out:
# [0.0055644793599725585,
#  0.00762846660364644,
#  0.011749058717741132,
#  0.015599509852322438,
#  0.018111262549433987,
#  0.03504427377414214,
#  0.04892389581669526,
#  0.12497422654671285,
#  0.21824899401101255,
#  0.27150730556752606]

# %%
# feature importances for entire model
first_map = dict(zip(tfidf_vectorizer.get_feature_names(), X_t.toarray()[0]))
# Out:
# str

# %%
# feature importances for model with ds/da words removed
second_map = dict(zip(tfidf_vectorizer.get_feature_names(), X_t_2.toarray()[0]))

# %%
for k, v in sorted(first_map.items(), key=lambda v: v[1], reverse=False):
    if v > 0.00:
        print(k, v)
# Out:
# business 0.025165059476156586
# years 0.025505856061991704
# ability 0.02856444795043758
# knowledge 0.030084451209372073
# responsibilities 0.03142196705089656
# role 0.03170781472731846
# support 0.03232609854142378
# development 0.03293143415713369
# requirements 0.034314777028703336
# engineering 0.035729719719219614
# degree 0.03605034168305703
# understanding 0.036131368448421824
# help 0.036459052931611016
# use 0.03783077973091068
# create 0.039215708349365816
# drive 0.03940841072906059
# opportunities 0.03960313097140501
# bachelor 0.04009904337965895
# needs 0.04139996623548871
# results 0.04139996623548871
# well 0.04200252777652709
# apply 0.04217030888372943
# quality 0.042226574019634366
# computer_science 0.04251048202637372
# s_degree 0.042740771201465445
# also 0.042798791882637646
# mathematics 0.04297394809032143
# communicate 0.04344926120611176
# algorithms 0.045482203763054826
# minimum 0.04651747738350934
# professional 0.047241133412761024
# mining 0.04738930641370574
# languages 0.047613803465022336
# master 0.04768924216170796
# learning 0.04791741205783795
# processing 0.04902086532937118
# applications 0.0495145831765522
# deep 0.0495145831765522
# high 0.0495145831765522
# variety 0.04968211235675975
# analyzing 0.04976644634815204
# team 0.049927079441274225
# language 0.05028064352998313
# findings 0.05080946437625497
# perform 0.05098913353462944
# analysis 0.05189339197021591
# dashboards 0.05249262785235437
# analytic 0.05278858550359744
# take 0.05278858550359744
# data_driven 0.053395017936013284
# meet 0.05500371035794841
# questions 0.05500371035794841
# independently 0.055116070900583715
# innovation 0.05522911449022564
# applied 0.05557242787021576
# familiarity 0.05664211902729499
# working 0.057074878133268045
# relational 0.05739103687891605
# python 0.05740016790194684
# methodologies 0.05857419571097494
# improvement 0.05912521715856375
# wide 0.05912521715856375
# leader 0.059983628633084755
# record 0.0602788032946551
# managing 0.06073054080997704
# proficient 0.060883591988607065
# extract 0.061037913316018676
# structured 0.06166833345886631
# natural 0.06199174357972668
# using 0.06215692297808532
# physics 0.06232087806979637
# unstructured 0.0626559432291014
# presentations 0.0629971567148733
# solving 0.06317014041093247
# scalable 0.06424326196554266
# scripting 0.06424326196554266
# clinical 0.06538212473330372
# interest 0.06538212473330372
# solutions 0.06552259854398468
# generation 0.06618205938847307
# produce 0.06638753786845035
# initiative 0.06659531224487225
# solid 0.06659531224487225
# collect 0.06680543440404202
# tool 0.06767050262222805
# architecture 0.068118611371175
# oriented 0.06881169581335575
# prior 0.06881169581335575
# insights 0.06885115089844668
# portfolio 0.06928853253531078
# machine_learning 0.06952397535494476
# explore 0.06953161590824435
# technical 0.0697509825284516
# structures 0.07079711178969023
# via 0.07079711178969023
# models 0.07106420483190395
# robust 0.07132845117232804
# real_world 0.07159992479998176
# analyst 0.07267098717025287
# complex 0.07316687753632255
# modeling 0.0734173244521638
# techniques 0.0734173244521638
# patient 0.0736200376909264
# build 0.07383852064658847
# query 0.07392741019696802
# uncover 0.07423994886868525
# player 0.07521037495074573
# problems 0.07548403537077744
# executing 0.07658845813815368
# extracting 0.07694954935241342
# successfully 0.07731779135054508
# array 0.07846840242651813
# experimentation 0.07846840242651813
# given 0.0792770347493997
# interpreting 0.0792770347493997
# quantitative 0.07989775220828425
# processes 0.07999759448692986
# software 0.08121708821310328
# advocate 0.08146728252548571
# exploration 0.08193808269058535
# biggest 0.08342652592434033
# responsible 0.08445314803926873
# administrative 0.08448942168093111
# engagements 0.08448942168093111
# sql 0.08512861324740562
# steps 0.08561677370042632
# process 0.0858307583626767
# field 0.08594789618064286
# technologies 0.08642017206924751
# improve 0.08653918409547458
# electronic 0.08744732722076501
# client 0.08775073182728824
# analytics 0.08792676987124752
# functionality 0.08809987183169508
# work 0.08932288844551027
# mastery 0.08947795501910304
# databases 0.09016742217558621
# evidence 0.09175782038179507
# health 0.09233188607081044
# highly 0.09261152066983082
# substantial 0.09344949638412677
# customers 0.09448226682552205
# nltk 0.09531060967014306
# reproducible 0.09631602280528968
# develop 0.0967801183654572
# statistical 0.09717717939887113
# experience 0.0973485970659053
# technically 0.09737891856188047
# preferred 0.1010972757626448
# scientist 0.10349942859826916
# production_ready 0.10385589513380737
# concepts 0.10658512501504745
# analytically 0.10920551968623904
# authoring 0.10920551968623904
# design 0.10937715879483305
# healthcare 0.11114485574043152
# applying 0.1130403602858928
# kit 0.1138788655935938
# minded 0.1138788655935938
# ai 0.11660937870528242
# executed 0.1167453920147567
# outcomes 0.11714839142194988
# driven 0.11996725726616951
# large_scale 0.12270090397547179
# co_operative 0.12428526434327439
# date_sources 0.12428526434327439
# packages_ 0.12428526434327439
# sr 0.21731690088963915
# data 0.24505457133400907

# %%
df_first_map = pd.DataFrame.from_dict(first_map, orient='index')
df_first_map.columns = ['importance']
df_first_map = df_first_map[df_first_map.importance > 0.00]
df_first_map.sort_values(by='importance', ascending=False)
# Out:
#                   importance
# data                0.245055
# sr                  0.217317
# packages_           0.124285
# co_operative        0.124285
# date_sources        0.124285
# large_scale         0.122701
# driven              0.119967
# outcomes            0.117148
# executed            0.116745
# ai                  0.116609
# kit                 0.113879
# minded              0.113879
# applying            0.113040
# healthcare          0.111145
# design              0.109377
# analytically        0.109206
# authoring           0.109206
# concepts            0.106585
# production_ready    0.103856
# scientist           0.103499
# preferred           0.101097
# technically         0.097379
# experience          0.097349
# statistical         0.097177
# develop             0.096780
# reproducible        0.096316
# nltk                0.095311
# customers           0.094482
# substantial         0.093449
# highly              0.092612
# ...                      ...
# minimum             0.046517
# algorithms          0.045482
# communicate         0.043449
# mathematics         0.042974
# also                0.042799
# s_degree            0.042741
# computer_science    0.042510
# quality             0.042227
# apply               0.042170
# well                0.042003
# needs               0.041400
# results             0.041400
# bachelor            0.040099
# opportunities       0.039603
# drive               0.039408
# create              0.039216
# use                 0.037831
# help                0.036459
# understanding       0.036131
# degree              0.036050
# engineering         0.035730
# requirements        0.034315
# development         0.032931
# support             0.032326
# role                0.031708
# responsibilities    0.031422
# knowledge           0.030084
# ability             0.028564
# years               0.025506
# business            0.025165
#
# [169 rows x 1 columns]

# %%
df_second_map = pd.DataFrame.from_dict(second_map, orient='index')
df_second_map.columns = ['importance']
df_second_map = df_second_map[df_second_map.importance > 0.00]
df_second_map.sort_values(by='importance', ascending=False)
# Out:
#                   importance
# data                0.245055
# sr                  0.217317
# packages_           0.124285
# co_operative        0.124285
# date_sources        0.124285
# large_scale         0.122701
# driven              0.119967
# outcomes            0.117148
# executed            0.116745
# ai                  0.116609
# kit                 0.113879
# minded              0.113879
# applying            0.113040
# healthcare          0.111145
# design              0.109377
# analytically        0.109206
# authoring           0.109206
# concepts            0.106585
# production_ready    0.103856
# scientist           0.103499
# preferred           0.101097
# technically         0.097379
# experience          0.097349
# statistical         0.097177
# develop             0.096780
# reproducible        0.096316
# nltk                0.095311
# customers           0.094482
# substantial         0.093449
# highly              0.092612
# ...                      ...
# minimum             0.046517
# algorithms          0.045482
# communicate         0.043449
# mathematics         0.042974
# also                0.042799
# s_degree            0.042741
# computer_science    0.042510
# quality             0.042227
# apply               0.042170
# well                0.042003
# needs               0.041400
# results             0.041400
# bachelor            0.040099
# opportunities       0.039603
# drive               0.039408
# create              0.039216
# use                 0.037831
# help                0.036459
# understanding       0.036131
# degree              0.036050
# engineering         0.035730
# requirements        0.034315
# development         0.032931
# support             0.032326
# role                0.031708
# responsibilities    0.031422
# knowledge           0.030084
# ability             0.028564
# years               0.025506
# business            0.025165
#
# [169 rows x 1 columns]
