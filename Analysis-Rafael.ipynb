# %%
import pandas as pd
import numpy as np

from nltk.corpus import stopwords
from gensim.models import Word2Vec, Doc2Vec, TfidfModel
from gensim.models.phrases import Phraser, Phrases

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
stopword_set = stopwords.words('english')

# %%
stopword_set = stopword_set + ["need", "goal", "include", "looking", "seeking"]

# %%
df = pd.read_csv("Raw_Data/jobs.csv")
df.head()
# Out:
#                        company  \
# 0                      Loftium
# 1                    Zume Inc.
# 2  TRC Staffing Services, Inc.
# 3                        bidco
# 4                    Compass /
#
#                                          description           job_cat  \
# 0  About the role\nMachine learning is core to ou...  machine learning
# 1  Who We Are\n\nZume is on a quest to be the mos...  machine learning
# 2  The goal is to lead the processes from infrast...  machine learning
# 3  We are looking for a Machine Learning Engineer...  machine learning
# 4  Engineering\n\nMachine Learning Engineer\n\nSe...  machine learning
#
#            loc                            location  \
# 0  Seattle, WA  Seattle, Washington, United States
# 1  Seattle, WA                     Seattle, WA, US
# 2  Seattle, WA                     Seattle, WA, US
# 3  Seattle, WA                     Seattle, WA, US
# 4  Seattle, WA                     Seattle, WA, US
#
#                                position position_low
# 0             Machine Learning Engineer          NaN
# 1  Machine Learning Engineer - Platform          NaN
# 2             Machine Learning Engineer          NaN
# 3             Machine Learning Engineer          NaN
# 4             Machine Learning Engineer          NaN

# %%
descriptions = df["description"]

# %%
def cleaner(text, stopwords=stopwords.words('english'), symbols = "?&()*%$#@.!:;^"):
    text = text.replace("\n", " ").replace("*", "").strip().strip("\n").replace("-", "_")
    for symbol in symbols:
        text = text.replace(symbol, "")
    text = text.lower()
    new_text = []
    for word in text.split(" "):
        if word in stopwords or word == ' ' or word == '':
            continue
        else:
            new_text.append(word)
    return new_text

# %%
descriptions = [cleaner(d, stopwords=stopword_set) for d in descriptions]

# %%
df['cleaned_descriptions'] = descriptions

# %%
bigram = Phrases(sentences = descriptions, min_count=1, threshold=1)

# %%
phrased_descriptions = [bigram[d] for d in descriptions]

# %%
df['phrased_descriptions'] = phrased_descriptions

# %%
df.head()
# Out:
#                        company  \
# 0                      Loftium
# 1                    Zume Inc.
# 2  TRC Staffing Services, Inc.
# 3                        bidco
# 4                    Compass /
#
#                                          description           job_cat  \
# 0  About the role\nMachine learning is core to ou...  machine learning
# 1  Who We Are\n\nZume is on a quest to be the mos...  machine learning
# 2  The goal is to lead the processes from infrast...  machine learning
# 3  We are looking for a Machine Learning Engineer...  machine learning
# 4  Engineering\n\nMachine Learning Engineer\n\nSe...  machine learning
#
#            loc                            location  \
# 0  Seattle, WA  Seattle, Washington, United States
# 1  Seattle, WA                     Seattle, WA, US
# 2  Seattle, WA                     Seattle, WA, US
# 3  Seattle, WA                     Seattle, WA, US
# 4  Seattle, WA                     Seattle, WA, US
#
#                                position position_low  \
# 0             Machine Learning Engineer          NaN
# 1  Machine Learning Engineer - Platform          NaN
# 2             Machine Learning Engineer          NaN
# 3             Machine Learning Engineer          NaN
# 4             Machine Learning Engineer          NaN
#
#                                 phrased_descriptions  \
# 0  [role, machine_learning, core_business,, drivi...
# 1  [zume, quest_powerful, source, health_well_bei...
# 2  [lead, processes, infrastructure, config, data...
# 3  [machine_learning, engineer_help, us_create, a...
# 4  [engineering, machine_learning, engineer_seatt...
#
#                                 cleaned_descriptions
# 0  [role, machine, learning, core, business,, dri...
# 1  [zume, quest, powerful, source, health, well_b...
# 2  [lead, processes, infrastructure, config, data...
# 3  [machine, learning, engineer, help, us, create...
# 4  [engineering, machine, learning, engineer, sea...

# %%
df.description[0]
# Out:
# "About the role\nMachine learning is core to our business, driving everything from our long-term and short-term rental income prediction algorithms to our revenue optimization algorithms and our properties acquisition pipeline. We're looking for a talented, experienced ML engineer to help us scale quickly, smartly and nimbly. This role offers a unique opportunity to join an amazing team and grow your career as quickly as Loftium scales.This role reports to our Head of Machine Learning.\n\nResponsibilities:\nBuild machine learning products that help drive our business\nMake thoughtful architectural decisions with limited information translating business requirements into machine learning products\nCommunicate decision rationales, formulating project plans and delivering results\nAutomating model comparison and feature selection to optimize performance\nShipping code to our staging and production environments multiple times a day\nBuilding data pipelines that allow us to improve our machine learning products and services\nDesign and deploy efficient data services and stores\n\nWho we're looking for:\nYou have 5+ years experience leveraging machine learning to solve complex business problems\nYou’re adaptable: You thrive in a fast-paced, ever-changing environment, and understand that the right solution and the perfect solution rarely coincide in startups\nExcited about Loftium’s mission of making housing more affordable\nBonus: Masters or PhD in computer science or other STEM degree \n\nYou have some experience with:\nPython and SQL (Both required)\nDesigning and deploying scalable production machine learning products\nMachine learning algorithms (Neural networks, gradient boosting) and model evaluation (cross validation, bias-variance trade-off)\nArchitecting relational databases (PostgreSQL), NoSQL databases (MongoDB), and data warehouses\nGit and GitHub; software development workflows\nManaging deployment & operation of cloud services (AWS, Azure etc.)\nLeveraging data pipeline frameworks (Airflow, Luigi, Pinball)\nWeb scraping, mobile api reverse engineering (Crawlera, Charles)\nBig data tools (Kafka, Spark, HDFS)\nBonus: Early-stage startup experience, especially joining at the seed or Series A stage and scaling a technical product\n\n***Visa sponsorship currently not available***"

# %%
df.cleaned_descriptions[0]
# Out:
# ['role',
#  'machine',
#  'learning',
#  'core',
#  'business,',
#  'driving',
#  'everything',
#  'long_term',
#  'short_term',
#  'rental',
#  'income',
#  'prediction',
#  'algorithms',
#  'revenue',
#  'optimization',
#  'algorithms',
#  'properties',
#  'acquisition',
#  'pipeline',
#  "we're",
#  'talented,',
#  'experienced',
#  'ml',
#  'engineer',
#  'help',
#  'us',
#  'scale',
#  'quickly,',
#  'smartly',
#  'nimbly',
#  'role',
#  'offers',
#  'unique',
#  'opportunity',
#  'join',
#  'amazing',
#  'team',
#  'grow',
#  'career',
#  'quickly',
#  'loftium',
#  'scalesthis',
#  'role',
#  'reports',
#  'head',
#  'machine',
#  'learning',
#  'responsibilities',
#  'build',
#  'machine',
#  'learning',
#  'products',
#  'help',
#  'drive',
#  'business',
#  'make',
#  'thoughtful',
#  'architectural',
#  'decisions',
#  'limited',
#  'information',
#  'translating',
#  'business',
#  'requirements',
#  'machine',
#  'learning',
#  'products',
#  'communicate',
#  'decision',
#  'rationales,',
#  'formulating',
#  'project',
#  'plans',
#  'delivering',
#  'results',
#  'automating',
#  'model',
#  'comparison',
#  'feature',
#  'selection',
#  'optimize',
#  'performance',
#  'shipping',
#  'code',
#  'staging',
#  'production',
#  'environments',
#  'multiple',
#  'times',
#  'day',
#  'building',
#  'data',
#  'pipelines',
#  'allow',
#  'us',
#  'improve',
#  'machine',
#  'learning',
#  'products',
#  'services',
#  'design',
#  'deploy',
#  'efficient',
#  'data',
#  'services',
#  'stores',
#  "we're",
#  '5+',
#  'years',
#  'experience',
#  'leveraging',
#  'machine',
#  'learning',
#  'solve',
#  'complex',
#  'business',
#  'problems',
#  'you’re',
#  'adaptable',
#  'thrive',
#  'fast_paced,',
#  'ever_changing',
#  'environment,',
#  'understand',
#  'right',
#  'solution',
#  'perfect',
#  'solution',
#  'rarely',
#  'coincide',
#  'startups',
#  'excited',
#  'loftium’s',
#  'mission',
#  'making',
#  'housing',
#  'affordable',
#  'bonus',
#  'masters',
#  'phd',
#  'computer',
#  'science',
#  'stem',
#  'degree',
#  'experience',
#  'python',
#  'sql',
#  'required',
#  'designing',
#  'deploying',
#  'scalable',
#  'production',
#  'machine',
#  'learning',
#  'products',
#  'machine',
#  'learning',
#  'algorithms',
#  'neural',
#  'networks,',
#  'gradient',
#  'boosting',
#  'model',
#  'evaluation',
#  'cross',
#  'validation,',
#  'bias_variance',
#  'trade_off',
#  'architecting',
#  'relational',
#  'databases',
#  'postgresql,',
#  'nosql',
#  'databases',
#  'mongodb,',
#  'data',
#  'warehouses',
#  'git',
#  'github',
#  'software',
#  'development',
#  'workflows',
#  'managing',
#  'deployment',
#  'operation',
#  'cloud',
#  'services',
#  'aws,',
#  'azure',
#  'etc',
#  'leveraging',
#  'data',
#  'pipeline',
#  'frameworks',
#  'airflow,',
#  'luigi,',
#  'pinball',
#  'web',
#  'scraping,',
#  'mobile',
#  'api',
#  'reverse',
#  'engineering',
#  'crawlera,',
#  'charles',
#  'big',
#  'data',
#  'tools',
#  'kafka,',
#  'spark,',
#  'hdfs',
#  'bonus',
#  'early_stage',
#  'startup',
#  'experience,',
#  'especially',
#  'joining',
#  'seed',
#  'series',
#  'stage',
#  'scaling',
#  'technical',
#  'product',
#  'visa',
#  'sponsorship',
#  'currently',
#  'available']

# %%
df.phrased_descriptions[0]
# Out:
# ['role',
#  'machine_learning',
#  'core_business,',
#  'driving',
#  'everything',
#  'long_term_short_term',
#  'rental',
#  'income',
#  'prediction_algorithms',
#  'revenue_optimization',
#  'algorithms',
#  'properties',
#  'acquisition',
#  'pipeline',
#  "we're",
#  'talented,',
#  'experienced_ml',
#  'engineer_help',
#  'us_scale',
#  'quickly,',
#  'smartly',
#  'nimbly',
#  'role_offers',
#  'unique_opportunity',
#  'join_amazing',
#  'team',
#  'grow_career',
#  'quickly',
#  'loftium',
#  'scalesthis',
#  'role_reports',
#  'head',
#  'machine_learning',
#  'responsibilities_build',
#  'machine_learning',
#  'products_help',
#  'drive_business',
#  'make',
#  'thoughtful',
#  'architectural_decisions',
#  'limited_information',
#  'translating_business',
#  'requirements',
#  'machine_learning',
#  'products',
#  'communicate',
#  'decision',
#  'rationales,',
#  'formulating',
#  'project_plans',
#  'delivering_results',
#  'automating',
#  'model',
#  'comparison',
#  'feature_selection',
#  'optimize_performance',
#  'shipping_code',
#  'staging',
#  'production_environments',
#  'multiple_times',
#  'day',
#  'building',
#  'data_pipelines',
#  'allow_us',
#  'improve',
#  'machine_learning',
#  'products_services',
#  'design_deploy',
#  'efficient',
#  'data',
#  'services',
#  'stores',
#  "we're_5+",
#  'years_experience',
#  'leveraging_machine',
#  'learning',
#  'solve_complex',
#  'business_problems',
#  'you’re',
#  'adaptable',
#  'thrive_fast_paced,',
#  'ever_changing',
#  'environment,',
#  'understand',
#  'right_solution',
#  'perfect',
#  'solution',
#  'rarely',
#  'coincide',
#  'startups',
#  'excited',
#  'loftium’s',
#  'mission_making',
#  'housing',
#  'affordable',
#  'bonus',
#  'masters_phd',
#  'computer_science',
#  'stem_degree',
#  'experience_python',
#  'sql_required',
#  'designing_deploying',
#  'scalable_production',
#  'machine_learning',
#  'products',
#  'machine_learning',
#  'algorithms_neural',
#  'networks,',
#  'gradient_boosting',
#  'model_evaluation',
#  'cross_validation,',
#  'bias_variance',
#  'trade_off',
#  'architecting',
#  'relational_databases',
#  'postgresql,',
#  'nosql_databases',
#  'mongodb,',
#  'data_warehouses',
#  'git',
#  'github',
#  'software_development',
#  'workflows',
#  'managing',
#  'deployment',
#  'operation',
#  'cloud_services',
#  'aws,_azure',
#  'etc',
#  'leveraging_data',
#  'pipeline_frameworks',
#  'airflow,_luigi,',
#  'pinball',
#  'web_scraping,',
#  'mobile',
#  'api',
#  'reverse_engineering',
#  'crawlera,',
#  'charles',
#  'big_data',
#  'tools_kafka,',
#  'spark,_hdfs',
#  'bonus',
#  'early_stage_startup',
#  'experience,_especially',
#  'joining',
#  'seed',
#  'series_stage',
#  'scaling',
#  'technical',
#  'product',
#  'visa_sponsorship',
#  'currently_available']

# %%
df["cleaned_phrased_descriptions"] = [' '.join(d) for d in df.phrased_descriptions]

# %%
df.head()
# Out:
#                        company  \
# 0                      Loftium
# 1                    Zume Inc.
# 2  TRC Staffing Services, Inc.
# 3                        bidco
# 4                    Compass /
#
#                                          description           job_cat  \
# 0  About the role\nMachine learning is core to ou...  machine learning
# 1  Who We Are\n\nZume is on a quest to be the mos...  machine learning
# 2  The goal is to lead the processes from infrast...  machine learning
# 3  We are looking for a Machine Learning Engineer...  machine learning
# 4  Engineering\n\nMachine Learning Engineer\n\nSe...  machine learning
#
#            loc                            location  \
# 0  Seattle, WA  Seattle, Washington, United States
# 1  Seattle, WA                     Seattle, WA, US
# 2  Seattle, WA                     Seattle, WA, US
# 3  Seattle, WA                     Seattle, WA, US
# 4  Seattle, WA                     Seattle, WA, US
#
#                                position position_low  \
# 0             Machine Learning Engineer          NaN
# 1  Machine Learning Engineer - Platform          NaN
# 2             Machine Learning Engineer          NaN
# 3             Machine Learning Engineer          NaN
# 4             Machine Learning Engineer          NaN
#
#                                 phrased_descriptions  \
# 0  [role, machine_learning, core_business,, drivi...
# 1  [zume, quest_powerful, source, health_well_bei...
# 2  [lead, processes, infrastructure, config, data...
# 3  [machine_learning, engineer_help, us_create, a...
# 4  [engineering, machine_learning, engineer_seatt...
#
#                                 cleaned_descriptions  \
# 0  [role, machine, learning, core, business,, dri...
# 1  [zume, quest, powerful, source, health, well_b...
# 2  [lead, processes, infrastructure, config, data...
# 3  [machine, learning, engineer, help, us, create...
# 4  [engineering, machine, learning, engineer, sea...
#
#                         cleaned_phrased_descriptions
# 0  role machine_learning core_business, driving e...
# 1  zume quest_powerful source health_well_being w...
# 2  lead processes infrastructure config data_coll...
# 3  machine_learning engineer_help us_create artif...
# 4  engineering machine_learning engineer_seattle ...

# %%
df.cleaned_phrased_descriptions[0]
# Out:
# "role machine_learning core_business, driving everything long_term_short_term rental income prediction_algorithms revenue_optimization algorithms properties acquisition pipeline we're talented, experienced_ml engineer_help us_scale quickly, smartly nimbly role_offers unique_opportunity join_amazing team grow_career quickly loftium scalesthis role_reports head machine_learning responsibilities_build machine_learning products_help drive_business make thoughtful architectural_decisions limited_information translating_business requirements machine_learning products communicate decision rationales, formulating project_plans delivering_results automating model comparison feature_selection optimize_performance shipping_code staging production_environments multiple_times day building data_pipelines allow_us improve machine_learning products_services design_deploy efficient data services stores we're_5+ years_experience leveraging_machine learning solve_complex business_problems you’re adaptable thrive_fast_paced, ever_changing environment, understand right_solution perfect solution rarely coincide startups excited loftium’s mission_making housing affordable bonus masters_phd computer_science stem_degree experience_python sql_required designing_deploying scalable_production machine_learning products machine_learning algorithms_neural networks, gradient_boosting model_evaluation cross_validation, bias_variance trade_off architecting relational_databases postgresql, nosql_databases mongodb, data_warehouses git github software_development workflows managing deployment operation cloud_services aws,_azure etc leveraging_data pipeline_frameworks airflow,_luigi, pinball web_scraping, mobile api reverse_engineering crawlera, charles big_data tools_kafka, spark,_hdfs bonus early_stage_startup experience,_especially joining seed series_stage scaling technical product visa_sponsorship currently_available"

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
X = df.cleaned_phrased_descriptions
y = df.job_cat

# %%
tfidf = TfidfVectorizer()

# %%
X_t = tfidf.fit_transform(X)

# %%
X_t.toarray()
# Out:
# (3635, 104903)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_t.toarray(), y, test_size=0.20)

# %%
clf = RandomForestClassifier()

# %%
clf.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
clf.score(xtrain, ytrain)
# Out:
# 0.9948418156808804

# %%
clf.score(xtest, ytest)
# Out:
# 0.8101788170563962

# %%
top_10 = clf.feature_importances_.argsort()[-10:]

# %%
for index in top_10:
    print(tfidf.get_feature_names()[index])
# Out:
# architecture
# data_scientists
# data_pipeline
# data_engineering
# data
# machine_learning
# data_analyst
# data_engineer
# data_science
# data_scientist

# %%
sorted(clf.feature_importances_)[-10:]
# Out:
# [0.0037029815635264097,
#  0.004449839448428987,
#  0.004729146704267233,
#  0.005840377811517096,
#  0.006961058315575879,
#  0.010142766632406599,
#  0.011154746617437388,
#  0.015451252193096354,
#  0.017390792162151517,
#  0.02240457788219398]
